# %%
import requests
import pandas as pd

# %% [markdown]
# ### Worldwide Stats

# %%
# Convert an API JSON Response to a Python Dictionary

url = "https://disease.sh/v3/covid-19/all"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
worldwide = pd.DataFrame.from_dict(data, orient='index')

# %%
worldwide = worldwide.T

# %%
worldwide
# Out:
#         updated        cases  todayCases     deaths  todayDeaths    recovered  \
# 0  1.666634e+12  633001563.0     99521.0  6583273.0        377.0  612036719.0
#
#    todayRecovered      active  critical  casesPerOneMillion  ...  \
# 0        288798.0  14381571.0   38418.0             81208.0  ...
#
#           tests  testsPerOneMillion    population  oneCasePerPeople  \
# 0  6.775200e+09           852769.89  7.944934e+09               0.0
#
#    oneDeathPerPeople  oneTestPerPeople  activePerOneMillion  \
# 0                0.0               0.0              1810.16
#
#    recoveredPerOneMillion  criticalPerOneMillion  affectedCountries
# 0                77034.84                   4.84              230.0
#
# [1 rows x 21 columns]

# %%
file_name = 'data/worldwide.csv'

worldwide.to_csv(file_name, index=False)

# %% [markdown]
# ### All Countries

# %%
url = 'https://disease.sh/v3/covid-19/countries'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
# Convert a list of dictionaries using json_normalize().
allcountries=pd.json_normalize(data)

# %%
allcountries.head()
# Out:
#          updated      country   cases  todayCases  deaths  todayDeaths  \
# 0  1666634403118  Afghanistan  202199          50    7818            0
# 1  1666634403008      Albania  332772           0    3591            0
# 2  1666634403013      Algeria  270783           0    6881            0
# 3  1666634403223      Andorra   46449           0     155            0
# 4  1666634403137       Angola  103131           0    1917            0
#
#    recovered  todayRecovered  active  critical  ...  oneTestPerPeople  \
# 0     180190              18   14191      1124  ...                36
# 1     327594               0    1587         0  ...                 1
# 2     182387               0   81515         0  ...               196
# 3      46151               0     143        14  ...                 0
# 4     101155               0      59         0  ...                23
#
#    activePerOneMillion  recoveredPerOneMillion  criticalPerOneMillion  \
# ...

# %%
file_name = '//dallcountries.csv'

allcountries.to_csv(file_name, index=False)

# %% [markdown]
# ### All US States

# %%
url = 'https://disease.sh/v3/covid-19/states'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
# Convert a list of dictionaries using json_normalize().
states=pd.json_normalize(data)

# %%
states.head()
# Out:
#         state        updated     cases  todayCases  deaths  todayDeaths  \
# 0  California  1666633771129  11337474           0   96874            0
# 1       Texas  1666633771129   7989735           0   91584            0
# 2     Florida  1666633771129   7189354           0   82065            0
# 3    New York  1666633771129   6388383           0   72860            0
# 4    Illinois  1666633771129   3796038           0   39899            0
#
#    recovered  active  casesPerOneMillion  deathsPerOneMillion      tests  \
# 0          0  175631              286936                 2452  187393121
# 1          0   62536              275547                 3159   72733896
# 2          0   39214              334735                 3821   63551057
# 3          0   48723              328391                 3745  121126929
# 4          0   57385              299565                 3149   57898053
#
#    testsPerOneMillion  population
# 0             4742662    39512223
# ...

# %%
file_name = 'data/states.csv'

states.to_csv(file_name, index=False)

# %% [markdown]
# ### Vaccine Coverage

# %%
url = 'https://disease.sh/v3/covid-19/vaccine/coverage/countries?lastdays=1&fullData=false'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
# Convert a list of dictionaries using json_normalize().
vac = pd.json_normalize(data)

# %%
vac.head()
# Out:
#        country  timeline.10/24/22
# 0  Afghanistan           11977773
# 1      Albania            2991576
# 2      Algeria           15267442
# 3      Andorra             154320
# 4       Angola           22696229

# %%
file_name = 'data/vacallcountries.csv'

vac.to_csv(file_name, index=False)

# %% [markdown]
# ### Vaccine Coverage US States

# %%
url = 'https://disease.sh/v3/covid-19/vaccine/coverage/states?lastdays=1&fullData=False'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
# Convert a list of dictionaries using json_normalize().
USvac = pd.json_normalize(data)

# %%
USvac.head()
# Out:
#             state  timeline.10/24/22
# 0         Alabama            6671583
# 1          Alaska            1253333
# 2  American Samoa             114484
# 3         Arizona           13468387
# 4        Arkansas            4610829

# %%
file_name = 'data/vacstates.csv'

USvac.to_csv(file_name, index=False)
